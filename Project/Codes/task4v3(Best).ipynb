# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, SpatialDropout2D, BatchNormalization, Flatten, Activation, Conv2D, MaxPooling2D, Conv1D
from keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np

# Importing CIFAR 10 Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# train split to validation
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

train_x = x_train1.astype('float32') / 255 
valid_x = x_valid.astype('float32') / 255
test_x = x_test.astype('float32') / 255

print(y_train1.shape)

N = 10

# One-hot encoding
train_y = to_categorical(y_train1, N).reshape(-1,1,1,10)
valid_y = to_categorical(y_valid, N).reshape(-1,1,1,10)
test_y = to_categorical(y_test, N).reshape(-1,1,1,10)
print(train_y.shape)
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# (40000, 1)
# (40000, 1, 1, 10)
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    Alex_model = Sequential()
    
    Alex_model.add(Conv2D(64, kernel_size=(3,3), strides = 2, padding='same', input_shape=(32, 32, 3))) # 1st Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    Alex_model.add(Conv2D(192, kernel_size=(3,3), strides = 2, padding='same'))       # 2nd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(384, kernel_size=(3,3), strides = 2, padding='same'))       # 3rd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 2, padding='same'))       # 4th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 2, padding='same'))       # 5th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    #Alex_model.add(Flatten())
    
    Alex_model.add(Conv2D(4096, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(4096))                     # 6th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Conv2D(4096, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(4096))                     # 7th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Conv2D(10, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(10))                       # 8th Layer
    Alex_model.add(Activation('softmax'))
    
    return Alex_model


Alex_model = Model()
Alex_model.compile(loss='categorical_crossentropy',
                   optimizer=tf.keras.optimizers.Adam(),
                   metrics=['accuracy'])
Alex_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_54 (Conv2D)           (None, 16, 16, 64)        1792
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# spatial_dropout2d_45 (Spatia (None, 16, 16, 64)        0
# _________________________________________________________________
# activation_55 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 8, 8, 192)         110784
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 8, 8, 192)         768
# _________________________________________________________________
# spatial_dropout2d_46 (Spatia (None, 8, 8, 192)         0
# _________________________________________________________________
# activation_56 (Activation)   (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 4, 4, 384)         663936
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 4, 4, 384)         1536
# _________________________________________________________________
# spatial_dropout2d_47 (Spatia (None, 4, 4, 384)         0
# _________________________________________________________________
# activation_57 (Activation)   (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_48 (Spatia (None, 2, 2, 256)         0
# _________________________________________________________________
# activation_58 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 1, 1, 256)         590080
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_49 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# activation_59 (Activation)   (None, 1, 1, 256)         0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 1, 1, 4096)        1052672
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 1, 1, 4096)        16384
# _________________________________________________________________
# activation_60 (Activation)   (None, 1, 1, 4096)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 1, 1, 4096)        16384
# _________________________________________________________________
# activation_61 (Activation)   (None, 1, 1, 4096)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# activation_62 (Activation)   (None, 1, 1, 10)          0
# =================================================================
# Total params: 20,163,914
# Trainable params: 20,145,226
# Non-trainable params: 18,688
# _________________________________________________________________

# %%
# verbose = progress bar setting
history = Alex_model.fit(train_x, train_y, batch_size=128, epochs=100, verbose=1, validation_data=(valid_x, valid_y))
# Out:
# Epoch 1/100
# 313/313 [==============================] - 9s 25ms/step - loss: 2.7915 - accuracy: 0.2028 - val_loss: 2.9492 - val_accuracy: 0.1288
# Epoch 2/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.9529 - accuracy: 0.3509 - val_loss: 1.5747 - val_accuracy: 0.4266
# Epoch 3/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.7622 - accuracy: 0.4079 - val_loss: 1.4809 - val_accuracy: 0.4758
# Epoch 4/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.6470 - accuracy: 0.4483 - val_loss: 1.6190 - val_accuracy: 0.4384
# Epoch 5/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.6271 - accuracy: 0.4640 - val_loss: 1.6402 - val_accuracy: 0.4798
# Epoch 6/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.5309 - accuracy: 0.4954 - val_loss: 1.6305 - val_accuracy: 0.5303
# Epoch 7/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.4919 - accuracy: 0.5125 - val_loss: 1.2089 - val_accuracy: 0.5805
# Epoch 8/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.4483 - accuracy: 0.5323 - val_loss: 1.2453 - val_accuracy: 0.5678
# Epoch 9/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.3738 - accuracy: 0.5479 - val_loss: 1.3618 - val_accuracy: 0.5271
# Epoch 10/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.3649 - accuracy: 0.5592 - val_loss: 1.1062 - val_accuracy: 0.6115
# Epoch 11/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2897 - accuracy: 0.5757 - val_loss: 1.0251 - val_accuracy: 0.6422
# Epoch 12/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2779 - accuracy: 0.5858 - val_loss: 1.2006 - val_accuracy: 0.6146
# Epoch 13/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2419 - accuracy: 0.5939 - val_loss: 1.1584 - val_accuracy: 0.6082
# Epoch 14/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2010 - accuracy: 0.6077 - val_loss: 0.9482 - val_accuracy: 0.6646
# Epoch 15/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1707 - accuracy: 0.6161 - val_loss: 0.9348 - val_accuracy: 0.6711
# Epoch 16/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1512 - accuracy: 0.6205 - val_loss: 1.0317 - val_accuracy: 0.6380
# Epoch 17/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0806 - accuracy: 0.6364 - val_loss: 0.9204 - val_accuracy: 0.6830
# Epoch 18/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0920 - accuracy: 0.6358 - val_loss: 0.9187 - val_accuracy: 0.6830
# Epoch 19/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0382 - accuracy: 0.6495 - val_loss: 0.9951 - val_accuracy: 0.6891
# Epoch 20/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0508 - accuracy: 0.6549 - val_loss: 0.8753 - val_accuracy: 0.6971
# Epoch 21/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9856 - accuracy: 0.6662 - val_loss: 0.8617 - val_accuracy: 0.7003
# Epoch 22/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9568 - accuracy: 0.6731 - val_loss: 1.1068 - val_accuracy: 0.6160
# Epoch 23/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9657 - accuracy: 0.6717 - val_loss: 1.1208 - val_accuracy: 0.6275
# Epoch 24/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9319 - accuracy: 0.6882 - val_loss: 0.9214 - val_accuracy: 0.6783
# Epoch 25/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9252 - accuracy: 0.6881 - val_loss: 0.8375 - val_accuracy: 0.7097
# Epoch 26/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9200 - accuracy: 0.6916 - val_loss: 0.9385 - val_accuracy: 0.6815
# Epoch 27/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8965 - accuracy: 0.6967 - val_loss: 0.8687 - val_accuracy: 0.6995
# Epoch 28/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8564 - accuracy: 0.7051 - val_loss: 0.8356 - val_accuracy: 0.7091
# Epoch 29/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8726 - accuracy: 0.7023 - val_loss: 0.9377 - val_accuracy: 0.6737
# Epoch 30/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8562 - accuracy: 0.7111 - val_loss: 0.9638 - val_accuracy: 0.6678
# Epoch 31/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8419 - accuracy: 0.7178 - val_loss: 0.8989 - val_accuracy: 0.6921
# Epoch 32/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8164 - accuracy: 0.7251 - val_loss: 0.9901 - val_accuracy: 0.6627
# Epoch 33/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8120 - accuracy: 0.7234 - val_loss: 0.9610 - val_accuracy: 0.6776
# Epoch 34/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8072 - accuracy: 0.7249 - val_loss: 0.8148 - val_accuracy: 0.7340
# Epoch 35/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7881 - accuracy: 0.7308 - val_loss: 0.8039 - val_accuracy: 0.7281
# Epoch 36/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7813 - accuracy: 0.7355 - val_loss: 0.7929 - val_accuracy: 0.7269
# Epoch 37/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7786 - accuracy: 0.7375 - val_loss: 0.8703 - val_accuracy: 0.7072
# Epoch 38/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7484 - accuracy: 0.7434 - val_loss: 0.8342 - val_accuracy: 0.7142
# Epoch 39/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7273 - accuracy: 0.7541 - val_loss: 0.8329 - val_accuracy: 0.7174
# Epoch 40/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7214 - accuracy: 0.7526 - val_loss: 0.8407 - val_accuracy: 0.7160
# Epoch 41/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7189 - accuracy: 0.7553 - val_loss: 0.7667 - val_accuracy: 0.7423
# Epoch 42/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7112 - accuracy: 0.7537 - val_loss: 0.9933 - val_accuracy: 0.6745
# Epoch 43/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7014 - accuracy: 0.7615 - val_loss: 0.7658 - val_accuracy: 0.7361
# Epoch 44/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6787 - accuracy: 0.7660 - val_loss: 0.8875 - val_accuracy: 0.7070
# Epoch 45/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6787 - accuracy: 0.7678 - val_loss: 0.7870 - val_accuracy: 0.7343
# Epoch 46/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6870 - accuracy: 0.7648 - val_loss: 0.7917 - val_accuracy: 0.7362
# Epoch 47/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7051 - accuracy: 0.7633 - val_loss: 0.7914 - val_accuracy: 0.7363
# Epoch 48/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.6612 - accuracy: 0.7737 - val_loss: 0.7603 - val_accuracy: 0.7482
# Epoch 49/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6504 - accuracy: 0.7780 - val_loss: 0.7444 - val_accuracy: 0.7497
# Epoch 50/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6366 - accuracy: 0.7813 - val_loss: 0.7883 - val_accuracy: 0.7379
# Epoch 51/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6192 - accuracy: 0.7879 - val_loss: 0.7511 - val_accuracy: 0.7453
# Epoch 52/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6296 - accuracy: 0.7847 - val_loss: 0.7534 - val_accuracy: 0.7530
# Epoch 53/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5993 - accuracy: 0.7928 - val_loss: 0.8039 - val_accuracy: 0.7297
# Epoch 54/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6187 - accuracy: 0.7890 - val_loss: 0.7680 - val_accuracy: 0.7528
# Epoch 55/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6275 - accuracy: 0.7854 - val_loss: 0.9230 - val_accuracy: 0.7043
# Epoch 56/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6033 - accuracy: 0.7932 - val_loss: 0.7317 - val_accuracy: 0.7580
# Epoch 57/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.5964 - accuracy: 0.7970 - val_loss: 0.7867 - val_accuracy: 0.7440
# Epoch 58/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5738 - accuracy: 0.8022 - val_loss: 0.8072 - val_accuracy: 0.7392
# Epoch 59/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5861 - accuracy: 0.8022 - val_loss: 0.7702 - val_accuracy: 0.7446
# Epoch 60/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5582 - accuracy: 0.8078 - val_loss: 0.7677 - val_accuracy: 0.7502
# Epoch 61/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5545 - accuracy: 0.8088 - val_loss: 0.7711 - val_accuracy: 0.7458
# Epoch 62/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5427 - accuracy: 0.8135 - val_loss: 0.7396 - val_accuracy: 0.7603
# Epoch 63/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5688 - accuracy: 0.8039 - val_loss: 0.7279 - val_accuracy: 0.7616
# Epoch 64/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5441 - accuracy: 0.8102 - val_loss: 0.7612 - val_accuracy: 0.7487
# Epoch 65/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5393 - accuracy: 0.8156 - val_loss: 0.7462 - val_accuracy: 0.7585
# Epoch 66/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5304 - accuracy: 0.8201 - val_loss: 0.7632 - val_accuracy: 0.7539
# Epoch 67/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5145 - accuracy: 0.8211 - val_loss: 0.7675 - val_accuracy: 0.7522
# Epoch 68/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5259 - accuracy: 0.8204 - val_loss: 0.7761 - val_accuracy: 0.7441
# Epoch 69/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5115 - accuracy: 0.8253 - val_loss: 0.7443 - val_accuracy: 0.7618
# Epoch 70/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5049 - accuracy: 0.8281 - val_loss: 0.8251 - val_accuracy: 0.7334
# Epoch 71/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5017 - accuracy: 0.8280 - val_loss: 0.7487 - val_accuracy: 0.7617
# Epoch 72/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5057 - accuracy: 0.8291 - val_loss: 0.7754 - val_accuracy: 0.7539
# Epoch 73/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5005 - accuracy: 0.8299 - val_loss: 0.8073 - val_accuracy: 0.7452
# Epoch 74/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4805 - accuracy: 0.8339 - val_loss: 0.7600 - val_accuracy: 0.7589
# Epoch 75/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4752 - accuracy: 0.8374 - val_loss: 0.7340 - val_accuracy: 0.7632
# Epoch 76/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4639 - accuracy: 0.8388 - val_loss: 0.8170 - val_accuracy: 0.7424
# Epoch 77/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4655 - accuracy: 0.8392 - val_loss: 0.7532 - val_accuracy: 0.7600
# Epoch 78/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4768 - accuracy: 0.8353 - val_loss: 0.7818 - val_accuracy: 0.7501
# Epoch 79/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4694 - accuracy: 0.8353 - val_loss: 0.8241 - val_accuracy: 0.7408
# Epoch 80/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4713 - accuracy: 0.8383 - val_loss: 0.7543 - val_accuracy: 0.7667
# Epoch 81/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4519 - accuracy: 0.8399 - val_loss: 0.7569 - val_accuracy: 0.7644
# Epoch 82/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4389 - accuracy: 0.8479 - val_loss: 0.7971 - val_accuracy: 0.7495
# Epoch 83/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4600 - accuracy: 0.8411 - val_loss: 0.7685 - val_accuracy: 0.7576
# Epoch 84/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4429 - accuracy: 0.8485 - val_loss: 0.7573 - val_accuracy: 0.7621
# Epoch 85/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4532 - accuracy: 0.8456 - val_loss: 0.7998 - val_accuracy: 0.7542
# Epoch 86/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4324 - accuracy: 0.8512 - val_loss: 0.8028 - val_accuracy: 0.7512
# Epoch 87/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4404 - accuracy: 0.8470 - val_loss: 0.8100 - val_accuracy: 0.7485
# Epoch 88/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4320 - accuracy: 0.8527 - val_loss: 0.7570 - val_accuracy: 0.7673
# Epoch 89/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4294 - accuracy: 0.8543 - val_loss: 0.7711 - val_accuracy: 0.7601
# Epoch 90/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4343 - accuracy: 0.8505 - val_loss: 0.7517 - val_accuracy: 0.7644
# Epoch 91/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4218 - accuracy: 0.8539 - val_loss: 0.8254 - val_accuracy: 0.7461
# Epoch 92/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4180 - accuracy: 0.8551 - val_loss: 0.7710 - val_accuracy: 0.7635
# Epoch 93/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3994 - accuracy: 0.8606 - val_loss: 0.7631 - val_accuracy: 0.7652
# Epoch 94/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4023 - accuracy: 0.8604 - val_loss: 0.7433 - val_accuracy: 0.7670
# Epoch 95/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4020 - accuracy: 0.8615 - val_loss: 0.7448 - val_accuracy: 0.7684
# Epoch 96/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4101 - accuracy: 0.8611 - val_loss: 0.7407 - val_accuracy: 0.7673
# Epoch 97/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.3856 - accuracy: 0.8659 - val_loss: 0.8021 - val_accuracy: 0.7529
# Epoch 98/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3899 - accuracy: 0.8654 - val_loss: 0.8207 - val_accuracy: 0.7469
# Epoch 99/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4017 - accuracy: 0.8623 - val_loss: 0.7777 - val_accuracy: 0.7595
# Epoch 100/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3891 - accuracy: 0.8666 - val_loss: 0.7714 - val_accuracy: 0.7621

# %%
score = Alex_model.evaluate(test_x, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.7827406525611877
# Test accuracy: 0.7592999935150146

# %%
test_accuracy=np.array([np.ones((100))*score[1]])
test_loss=np.array([np.ones((100))*score[0]])
epoch=np.array([np.linspace(1,100,100)])


# Accuracy plots
plt.plot(history.history['accuracy'], marker='.', label='training accuracy')
plt.plot(history.history['val_accuracy'], marker='.', label='validation accuracy')
plt.plot(epoch,test_accuracy, marker='.')
plt.plot(epoch[0],test_accuracy[0], marker='.', label='Test accuracy')
plt.title(' accuracy')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.savefig('Task4_accuracyV3.jpeg')
plt.show()

# Loss plots
plt.plot(history.history['loss'], marker='.', label='training loss')
plt.plot(history.history['val_loss'], marker='.', label='validation loss')
plt.plot(epoch,test_loss, marker='.')
plt.plot(epoch[0],test_loss[0], marker='.',label='Test loss')
plt.title(' loss')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.savefig('Task4_lossV3.jpeg')
plt.show()
