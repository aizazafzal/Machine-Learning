# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, SpatialDropout2D, BatchNormalization, Flatten, Activation, Conv2D, MaxPooling2D, Conv1D
from keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np

# Importing CIFAR 10 Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# train split to validation
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

train_x = x_train1.astype('float32') / 255 
valid_x = x_valid.astype('float32') / 255
test_x = x_test.astype('float32') / 255

print(y_train1.shape)

N = 10

# One-hot encoding
train_y = to_categorical(y_train1, N)
valid_y = to_categorical(y_valid, N)
test_y = to_categorical(y_test, N)
print(train_y.shape)
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# (40000, 1)
# (40000, 10)
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    Alex_model = Sequential()
    
    Alex_model.add(Conv2D(64, kernel_size=(3,3), strides = 1, padding='same', input_shape=(32, 32, 3))) # 1st Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    Alex_model.add(Conv2D(192, kernel_size=(3,3), strides = 1, padding='same'))       # 2nd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(384, kernel_size=(3,3), strides = 1, padding='same'))       # 3rd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 1, padding='same'))       # 4th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 1, padding='same'))       # 5th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    Alex_model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    Alex_model.add(Flatten())
    
    Alex_model.add(Dense(4096))                     # 6th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Dense(4096))                     # 7th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Dense(10))                       # 8th Layer
    Alex_model.add(Activation('softmax'))
    return Alex_model


Alex_model = Model()
Alex_model.compile(loss='categorical_crossentropy',
                   optimizer=tf.keras.optimizers.Adam(),
                   metrics=['accuracy'])
Alex_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# spatial_dropout2d_15 (Spatia (None, 32, 32, 64)        0
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 192)       110784
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 16, 16, 192)       768
# _________________________________________________________________
# spatial_dropout2d_16 (Spatia (None, 16, 16, 192)       0
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 192)       0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 384)         663936
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 8, 8, 384)         1536
# _________________________________________________________________
# spatial_dropout2d_17 (Spatia (None, 8, 8, 384)         0
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 384)         0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 256)         884992
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_18 (Spatia (None, 4, 4, 256)         0
# _________________________________________________________________
# activation_10 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_19 (Spatia (None, 2, 2, 256)         0
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 4096)              16384
# _________________________________________________________________
# activation_12 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 4096)              16384
# _________________________________________________________________
# activation_13 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                40970
# _________________________________________________________________
# activation_14 (Activation)   (None, 10)                0
# =================================================================
# Total params: 20,163,914
# Trainable params: 20,145,226
# Non-trainable params: 18,688
# _________________________________________________________________

# %%
# verbose = progress bar setting
history = Alex_model.fit(train_x, train_y, batch_size=128, epochs=50, verbose=1, validation_data=(valid_x, valid_y))
# Out:
# Epoch 1/50
# 313/313 [==============================] - 8s 23ms/step - loss: 2.6275 - accuracy: 0.2250 - val_loss: 3.2292 - val_accuracy: 0.1218
# Epoch 2/50
# 313/313 [==============================] - 7s 21ms/step - loss: 1.7785 - accuracy: 0.4092 - val_loss: 2.4443 - val_accuracy: 0.4604
# Epoch 3/50
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5688 - accuracy: 0.4796 - val_loss: 1.2972 - val_accuracy: 0.5415
# Epoch 4/50
# 313/313 [==============================] - 6s 21ms/step - loss: 1.3931 - accuracy: 0.5410 - val_loss: 1.1746 - val_accuracy: 0.5763
# Epoch 5/50
# 313/313 [==============================] - 7s 21ms/step - loss: 1.2723 - accuracy: 0.5798 - val_loss: 1.3315 - val_accuracy: 0.5982
# Epoch 6/50
# 313/313 [==============================] - 7s 21ms/step - loss: 1.2084 - accuracy: 0.6052 - val_loss: 0.9664 - val_accuracy: 0.6671
# Epoch 7/50
# 313/313 [==============================] - 7s 21ms/step - loss: 1.0867 - accuracy: 0.6390 - val_loss: 0.8932 - val_accuracy: 0.6934
# Epoch 8/50
# 313/313 [==============================] - 7s 21ms/step - loss: 1.0274 - accuracy: 0.6584 - val_loss: 0.8861 - val_accuracy: 0.6952
# Epoch 9/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.9651 - accuracy: 0.6775 - val_loss: 0.9407 - val_accuracy: 0.6995
# Epoch 10/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.9234 - accuracy: 0.6936 - val_loss: 0.8163 - val_accuracy: 0.7228
# Epoch 11/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0
50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.3367 - accuracy: 0.8831 - val_loss: 0.6933 - val_accuracy: 0.7936
# Epoch 36/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.3336 - accuracy: 0.8848 - val_loss: 0.7128 - val_accuracy: 0.7965
# Epoch 37/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.3294 - accuracy: 0.8881 - val_loss: 1.4088 - val_accuracy: 0.6571
# Epoch 38/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.3174 - accuracy: 0.8896 - val_loss: 0.7842 - val_accuracy: 0.7782
# Epoch 39/50
# 313/313 [==============================] - 6s 21ms/step - loss: 0.2941 - accuracy: 0.8990 - val_loss: 0.7001 - val_accuracy: 0.8001
# Epoch 40/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2837 - accuracy: 0.9019 - val_loss: 0.6508 - val_accuracy: 0.8135
# Epoch 41/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2741 - accuracy: 0.9053 - val_loss: 0.8020 - val_accuracy: 0.7801
# Epoch 42/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2682 - accuracy: 0.9068 - val_loss: 0.6838 - val_accuracy: 0.8084
# Epoch 43/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2749 - accuracy: 0.9077 - val_loss: 0.6516 - val_accuracy: 0.8156
# Epoch 44/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2606 - accuracy: 0.9088 - val_loss: 0.6845 - val_accuracy: 0.8083
# Epoch 45/50
# 313/313 [==============================] - 7s 22ms/step - loss: 0.2447 - accuracy: 0.9172 - val_loss: 0.6476 - val_accuracy: 0.8158
# Epoch 46/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2376 - accuracy: 0.9180 - val_loss: 0.6874 - val_accuracy: 0.8132
# Epoch 47/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2384 - accuracy: 0.9185 - val_loss: 0.7417 - val_accuracy: 0.8046
# Epoch 48/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2385 - accuracy: 0.9186 - val_loss: 0.6650 - val_accuracy: 0.8168
# Epoch 49/50
# 313/313 [==============================] - 7s 21ms/step - loss: 0.2174 - accuracy: 0.9250 - val_loss: 0.6857 - val_accuracy: 0.8126
# Epoch 50/50
# 313/313 [==============================] - 7s 22ms/step - loss: 0.2395 - accuracy: 0.9193 - val_loss: 0.6947 - val_accuracy: 0.8144

# %%
score = Alex_model.evaluate(test_x, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.7112584710121155
# Test accuracy: 0.8137000203132629

# %%
test_accuracy=np.array([np.ones((50))*score[1]])
test_loss=np.array([np.ones((50))*score[0]])
epoch=np.array([np.linspace(1,50,50)])


# Accuracy plots
plt.plot(history.history['accuracy'], marker='.', label='training accuracy')
plt.plot(history.history['val_accuracy'], marker='.', label='validation accuracy')
plt.plot(epoch,test_accuracy, marker='.')
plt.plot(epoch[0],test_accuracy[0], marker='.', label='Test accuracy')
plt.title(' accuracy')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.savefig('Task3_accuracyV2.jpeg')
plt.show()

# Loss plots
plt.plot(history.history['loss'], marker='.', label='training loss')
plt.plot(history.history['val_loss'], marker='.', label='validation loss')
plt.plot(epoch,test_loss, marker='.')
plt.plot(epoch[0],test_loss[0], marker='.',label='Test loss')
plt.title(' loss')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.savefig('Task3_lossV2.jpeg')
plt.show()
