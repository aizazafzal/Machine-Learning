# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten,SpatialDropout2D
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np

# Importing CIFAR 10 Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# train split to validation
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

train_x = x_train1.astype('float32') / 255 
valid_x = x_valid.astype('float32') / 255
test_x = x_test.astype('float32') / 255

print(y_train1.shape)

N = 10

# One-hot encoding
train_y = to_categorical(y_train1, N)
valid_y = to_categorical(y_valid, N)
test_y = to_categorical(y_test, N)
print(train_y.shape)
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# (40000, 1)
# (40000, 10)
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    Alex_model = Sequential()
    
    Alex_model.add(Conv2D(64, kernel_size=(3,3), strides = 1, padding='same', activation='relu', input_shape=(32, 32, 3))) # 1st Layer
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    Alex_model.add(Conv2D(192, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 2nd Layer
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(384, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 3rd Layer
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 4th Layer
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 1, padding='same', activation='relu'))       # 5th Layer
    Alex_model.add(SpatialDropout2D(rate=0.4))
    Alex_model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    Alex_model.add(Flatten())
    
    Alex_model.add(Dense(4096, activation='relu'))                     # 6th Layer
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Dense(4096, activation='relu'))                     # 7th Layer
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Dense(10,activation='softmax'))                     # 8th Layer
    return Alex_model


Alex_model = Model()
Alex_model.compile(loss='categorical_crossentropy',
                   optimizer=tf.keras.optimizers.Adam(),
                   metrics=['accuracy'])
Alex_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 192)       110784
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 16, 16, 192)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         663936
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 8, 8, 384)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         884992
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         590080
# _________________________________________________________________
# spatial_dropout2d_4 (Spatial (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 20,126,538
# Trainable params: 20,126,538
# Non-trainable params: 0
# _________________________________________________________________

# %%
# verbose = progress bar setting
history = Alex_model.fit(train_x, train_y, batch_size=128, epochs=50, verbose=1, validation_data=(valid_x, valid_y))
# Out:
# Epoch 1/50
# 313/313 [==============================] - 14s 21ms/step - loss: 2.1325 - accuracy: 0.1775 - val_loss: 1.6976 - val_accuracy: 0.3322
# Epoch 2/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.7723 - accuracy: 0.3256 - val_loss: 1.5142 - val_accuracy: 0.4473
# Epoch 3/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.6471 - accuracy: 0.3874 - val_loss: 1.4522 - val_accuracy: 0.4880
# Epoch 4/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.5646 - accuracy: 0.4263 - val_loss: 1.3729 - val_accuracy: 0.5044
# Epoch 5/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.5028 - accuracy: 0.4470 - val_loss: 1.3106 - val_accuracy: 0.5177
# Epoch 6/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.4602 - accuracy: 0.4682 - val_loss: 1.3014 - val_accuracy: 0.5227
# Epoch 7/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.4091 - accuracy: 0.4937 - val_loss: 1.1792 - val_accuracy: 0.5772
# Epoch 8/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.3776 - accuracy: 0.5092 - val_loss: 1.2989 - val_accuracy: 0.5317
# Epoch 9/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.3621 - accuracy: 0.5105 - val_loss: 1.1344 - val_accuracy: 0.5788
# Epoch 10/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.3338 - accuracy: 0.5243 - val_loss: 1.1209 - val_accuracy: 0.6017
# Epoch 11/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2999 - accuracy: 0.5338 - val_loss: 1.1306 - val_accuracy: 0.5995
# Epoch 12/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2818 - accuracy: 0.5405 - val_loss: 1.0568 - val_accuracy: 0.6235
# Epoch 13/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2625 - accuracy: 0.5503 - val_loss: 1.0234 - val_accuracy: 0.6390
# Epoch 14/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2489 - accuracy: 0.5573 - val_loss: 1.0945 - val_accuracy: 0.6062
# Epoch 15/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2310 - accuracy: 0.5625 - val_loss: 1.0353 - val_accuracy: 0.6323
# Epoch 16/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2096 - accuracy: 0.5727 - val_loss: 1.0218 - val_accuracy: 0.6382
# Epoch 17/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1996 - accuracy: 0.5800 - val_loss: 0.9988 - val_accuracy: 0.6572
# Epoch 18/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1935 - accuracy: 0.5799 - val_loss: 0.9604 - val_accuracy: 0.6628
# Epoch 19/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1695 - accuracy: 0.5911 - val_loss: 0.9986 - val_accuracy: 0.6512
# Epoch 20/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1700 - accuracy: 0.5953 - val_loss: 0.9598 - val_accuracy: 0.6705
# Epoch 21/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1539 - accuracy: 0.5962 - val_loss: 1.0089 - val_accuracy: 0.6541
# Epoch 22/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1645 - accuracy: 0.5947 - val_loss: 0.9974 - val_accuracy: 0.6530
# Epoch 23/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1591 - accuracy: 0.6015 - val_loss: 0.9494 - val_accuracy: 0.6736
# Epoch 24/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1387 - accuracy: 0.6043 - val_loss: 0.9603 - val_accuracy: 0.6703
# Epoch 25/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1217 - accuracy: 0.6096 - val_loss: 0.9295 - val_accuracy: 0.6856
# Epoch 26/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1165 - accuracy: 0.6158 - val_loss: 0.9499 - val_accuracy: 0.6741
# Epoch 27/50
# 313/313 [==============================] - 6s 19ms/step - loss: 1.1192 - accuracy: 0.6154 - val_loss: 0.9426 - val_accuracy: 0.6722
# Epoch 28/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1094 - accuracy: 0.6190 - val_loss: 0.9500 - val_accuracy: 0.6787
# Epoch 29/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1098 - accuracy: 0.6201 - val_loss: 0.9180 - val_accuracy: 0.6880
# Epoch 30/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0962 - accuracy: 0.6233 - val_loss: 0.9226 - val_accuracy: 0.6930
# Epoch 31/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.1102 - accuracy: 0.6184 - val_loss: 0.9334 - val_accuracy: 0.6958
# Epoch 32/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0838 - accuracy: 0.6295 - val_loss: 0.9242 - val_accuracy: 0.6985
# Epoch 33/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0875 - accuracy: 0.6312 - val_loss: 0.9183 - val_accuracy: 0.6917
# Epoch 34/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0767 - accuracy: 0.6325 - val_loss: 0.8987 - val_accuracy: 0.6981
# Epoch 35/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0790 - accuracy: 0.6368 - val_loss: 0.9219 - val_accuracy: 0.6955
# Epoch 36/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0791 - accuracy: 0.6290 - val_loss: 0.9189 - val_accuracy: 0.6926
# Epoch 37/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0677 - accuracy: 0.6363 - val_loss: 0.9022 - val_accuracy: 0.6951
# Epoch 38/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0643 - accuracy: 0.6384 - val_loss: 0.8857 - val_accuracy: 0.7093
# Epoch 39/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0733 - accuracy: 0.6308 - val_loss: 1.0772 - val_accuracy: 0.6437
# Epoch 40/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0673 - accuracy: 0.6386 - val_loss: 0.9026 - val_accuracy: 0.7036
# Epoch 41/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0491 - accuracy: 0.6417 - val_loss: 0.9035 - val_accuracy: 0.7007
# Epoch 42/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0640 - accuracy: 0.6387 - val_loss: 0.8907 - val_accuracy: 0.7133
# Epoch 43/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0500 - accuracy: 0.6440 - val_loss: 0.8657 - val_accuracy: 0.7073
# Epoch 44/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0482 - accuracy: 0.6463 - val_loss: 0.8662 - val_accuracy: 0.7152
# Epoch 45/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0509 - accuracy: 0.6474 - val_loss: 0.8894 - val_accuracy: 0.7097
# Epoch 46/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0278 - accuracy: 0.6492 - val_loss: 0.8881 - val_accuracy: 0.7012
# Epoch 47/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0469 - accuracy: 0.6486 - val_loss: 0.8635 - val_accuracy: 0.7175
# Epoch 48/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0560 - accuracy: 0.6456 - val_loss: 0.8877 - val_accuracy: 0.7160
# Epoch 49/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0320 - accuracy: 0.6520 - val_loss: 0.8624 - val_accuracy: 0.7205
# Epoch 50/50
# 313/313 [==============================] - 6s 18ms/step - loss: 1.0309 - accuracy: 0.6559 - val_loss: 0.8764 - val_accuracy: 0.7088

# %%
score = Alex_model.evaluate(test_x, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.872353196144104
# Test accuracy: 0.7148000001907349

# %%
test_accuracy=np.array([np.ones((50))*score[1]])
test_loss=np.array([np.ones((50))*score[0]])
epoch=np.array([np.linspace(1,50,50)])


# Accuracy plots
plt.plot(history.history['accuracy'], marker='.', label='training accuracy')
plt.plot(history.history['val_accuracy'], marker='.', label='validation accuracy')
plt.plot(epoch,test_accuracy, marker='.')
plt.plot(epoch[0],test_accuracy[0], marker='.', label='Test accuracy')
plt.title(' accuracy')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.savefig('Task2_accuracyV3.jpeg')
plt.show()

# Loss plots
plt.plot(history.history['loss'], marker='.', label='training loss')
plt.plot(history.history['val_loss'], marker='.', label='validation loss')
plt.plot(epoch,test_loss, marker='.')
plt.plot(epoch[0],test_loss[0], marker='.',label='Test loss')
plt.title(' loss')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.savefig('Task2_lossV3.jpeg')
plt.show()
