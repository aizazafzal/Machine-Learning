# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, SpatialDropout2D, BatchNormalization, Flatten, Activation, Conv2D, MaxPooling2D, Conv1D
from keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np

# Importing CIFAR 10 Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# train split to validation
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

train_x = x_train1.astype('float32') / 255 
valid_x = x_valid.astype('float32') / 255
test_x = x_test.astype('float32') / 255

print(y_train1.shape)

N = 10

# One-hot encoding
train_y = to_categorical(y_train1, N).reshape(-1,1,1,10)
valid_y = to_categorical(y_valid, N).reshape(-1,1,1,10)
test_y = to_categorical(y_test, N).reshape(-1,1,1,10)
print(train_y.shape)
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# (40000, 1)
# (40000, 1, 1, 10)
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    Alex_model = Sequential()
    
    Alex_model.add(Conv2D(64, kernel_size=(3,3), strides = 2, padding='same', input_shape=(32, 32, 3))) # 1st Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.2))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    Alex_model.add(Conv2D(192, kernel_size=(3,3), strides = 2, padding='same'))       # 2nd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.2))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(384, kernel_size=(3,3), strides = 2, padding='same'))       # 3rd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.2))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 2, padding='same'))       # 4th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.2))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 2, padding='same'))       # 5th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.2))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    #Alex_model.add(Flatten())
    
    Alex_model.add(Conv2D(4096, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(4096))                     # 6th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Conv2D(4096, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(4096))                     # 7th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Conv2D(10, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(10))                       # 8th Layer
    Alex_model.add(Activation('softmax'))
    
    return Alex_model


Alex_model = Model()
Alex_model.compile(loss='categorical_crossentropy',
                   optimizer=tf.keras.optimizers.Adam(),
                   metrics=['accuracy'])
Alex_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 16, 16, 64)        1792
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# spatial_dropout2d_35 (Spatia (None, 16, 16, 64)        0
# _________________________________________________________________
# activation_39 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 8, 8, 192)         110784
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 8, 8, 192)         768
# _________________________________________________________________
# spatial_dropout2d_36 (Spatia (None, 8, 8, 192)         0
# _________________________________________________________________
# activation_40 (Activation)   (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 4, 4, 384)         663936
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 4, 4, 384)         1536
# _________________________________________________________________
# spatial_dropout2d_37 (Spatia (None, 4, 4, 384)         0
# _________________________________________________________________
# activation_41 (Activation)   (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_38 (Spatia (None, 2, 2, 256)         0
# _________________________________________________________________
# activation_42 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 1, 1, 256)         590080
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_39 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# activation_43 (Activation)   (None, 1, 1, 256)         0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 1, 1, 4096)        1052672
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 1, 1, 4096)        16384
# _________________________________________________________________
# activation_44 (Activation)   (None, 1, 1, 4096)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 1, 1, 4096)        16384
# _________________________________________________________________
# activation_45 (Activation)   (None, 1, 1, 4096)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# activation_46 (Activation)   (None, 1, 1, 10)          0
# =================================================================
# Total params: 20,163,914
# Trainable params: 20,145,226
# Non-trainable params: 18,688
# _________________________________________________________________

# %%
# verbose = progress bar setting
history = Alex_model.fit(train_x, train_y, batch_size=128, epochs=50, verbose=1, validation_data=(valid_x, valid_y))
# Out:
# Epoch 1/50
# 313/313 [==============================] - 9s 25ms/step - loss: 2.4771 - accuracy: 0.2767 - val_loss: 2.8973 - val_accuracy: 0.1343
# Epoch 2/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.6489 - accuracy: 0.4473 - val_loss: 1.7730 - val_accuracy: 0.4214
# Epoch 3/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.5000 - accuracy: 0.5107 - val_loss: 1.3570 - val_accuracy: 0.5499
# Epoch 4/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.3467 - accuracy: 0.5596 - val_loss: 1.1899 - val_accuracy: 0.5866
# Epoch 5/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2463 - accuracy: 0.5977 - val_loss: 1.7987 - val_accuracy: 0.5290
# Epoch 6/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1633 - accuracy: 0.6223 - val_loss: 1.1787 - val_accuracy: 0.5971
# Epoch 7/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0398 - accuracy: 0.6608 - val_loss: 1.0173 - val_accuracy: 0.6685
# Epoch 8/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9301 - accuracy: 0.6852 - val_loss: 0.9961 - val_accuracy: 0.6603
# Epoch 9/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8884 - accuracy: 0.7051 - val_loss: 0.9100 - val_accuracy: 0.6905
# Epoch 10/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.8288 - accuracy: 0.7239 - val_loss: 0.9437 - val_accuracy: 0.6864
# Epoch 11/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7692 - accuracy: 0.7456 - val_loss: 0.8514 - val_accuracy: 0.7071
# Epoch 12/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7209 - accuracy: 0.7582 - val_loss: 0.9360 - val_accuracy: 0.6946
# Epoch 13/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6412 - accuracy: 0.7795 - val_loss: 0.8449 - val_accuracy: 0.7216
# Epoch 14/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.6087 - accuracy: 0.7916 - val_loss: 1.1899 - val_accuracy: 0.6339
# Epoch 15/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5723 - accuracy: 0.8062 - val_loss: 1.0204 - val_accuracy: 0.6793
# Epoch 16/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5305 - accuracy: 0.8192 - val_loss: 0.9182 - val_accuracy: 0.7084
# Epoch 17/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5088 - accuracy: 0.8304 - val_loss: 0.9365 - val_accuracy: 0.7097
# Epoch 18/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4732 - accuracy: 0.8393 - val_loss: 0.9281 - val_accuracy: 0.7142
# Epoch 19/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4483 - accuracy: 0.8499 - val_loss: 0.9761 - val_accuracy: 0.7070
# Epoch 20/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4198 - accuracy: 0.8573 - val_loss: 0.8736 - val_accuracy: 0.7309
# Epoch 21/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3883 - accuracy: 0.8703 - val_loss: 0.9306 - val_accuracy: 0.7248
# Epoch 22/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4055 - accuracy: 0.8664 - val_loss: 0.9414 - val_accuracy: 0.7197
# Epoch 23/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.3518 - accuracy: 0.8831 - val_loss: 1.0017 - val_accuracy: 0.7203
# Epoch 24/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3294 - accuracy: 0.8872 - val_loss: 0.9849 - val_accuracy: 0.7133
# Epoch 25/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3086 - accuracy: 0.8974 - val_loss: 0.9166 - val_accuracy: 0.7424
# Epoch 26/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2822 - accuracy: 0.9052 - val_loss: 0.9401 - val_accuracy: 0.7333
# Epoch 27/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2716 - accuracy: 0.9070 - val_loss: 0.9978 - val_accuracy: 0.7235
# Epoch 28/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2740 - accuracy: 0.9087 - val_loss: 0.9916 - val_accuracy: 0.7299
# Epoch 29/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2696 - accuracy: 0.9107 - val_loss: 0.9885 - val_accuracy: 0.7356
# Epoch 30/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2731 - accuracy: 0.9098 - val_loss: 1.0152 - val_accuracy: 0.7301
# Epoch 31/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2377 - accuracy: 0.9198 - val_loss: 1.0114 - val_accuracy: 0.7395
# Epoch 32/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.2113 - accuracy: 0.9269 - val_loss: 0.9869 - val_accuracy: 0.7332
# Epoch 33/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2335 - accuracy: 0.9226 - val_loss: 1.0102 - val_accuracy: 0.7353
# Epoch 34/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2265 - accuracy: 0.9263 - val_loss: 1.0975 - val_accuracy: 0.7155
# Epoch 35/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.2025 - accuracy: 0.9319 - val_loss: 1.0874 - val_accuracy: 0.7180
# Epoch 36/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1940 - accuracy: 0.9344 - val_loss: 1.0393 - val_accuracy: 0.7332
# Epoch 37/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1857 - accuracy: 0.9369 - val_loss: 1.0731 - val_accuracy: 0.7291
# Epoch 38/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1769 - accuracy: 0.9409 - val_loss: 1.1548 - val_accuracy: 0.7180
# Epoch 39/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1945 - accuracy: 0.9352 - val_loss: 1.0065 - val_accuracy: 0.7373
# Epoch 40/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1923 - accuracy: 0.9371 - val_loss: 1.0832 - val_accuracy: 0.7318
# Epoch 41/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1734 - accuracy: 0.9405 - val_loss: 1.1091 - val_accuracy: 0.7355
# Epoch 42/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1559 - accuracy: 0.9489 - val_loss: 1.1108 - val_accuracy: 0.7285
# Epoch 43/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1425 - accuracy: 0.9527 - val_loss: 1.1129 - val_accuracy: 0.7355
# Epoch 44/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1380 - accuracy: 0.9535 - val_loss: 1.1274 - val_accuracy: 0.7334
# Epoch 45/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.1390 - accuracy: 0.9535 - val_loss: 1.2003 - val_accuracy: 0.7198
# Epoch 46/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1769 - accuracy: 0.9438 - val_loss: 1.0501 - val_accuracy: 0.7409
# Epoch 47/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1680 - accuracy: 0.9466 - val_loss: 1.1955 - val_accuracy: 0.7080
# Epoch 48/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1955 - accuracy: 0.9349 - val_loss: 1.0963 - val_accuracy: 0.7362
# Epoch 49/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1506 - accuracy: 0.9500 - val_loss: 1.1470 - val_accuracy: 0.7416
# Epoch 50/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.1305 - accuracy: 0.9541 - val_loss: 1.0893 - val_accuracy: 0.7440

# %%
score = Alex_model.evaluate(test_x, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.1395500898361206
# Test accuracy: 0.7348999977111816

# %%
test_accuracy=np.array([np.ones((50))*score[1]])
test_loss=np.array([np.ones((50))*score[0]])
epoch=np.array([np.linspace(1,50,50)])


# Accuracy plots
plt.plot(history.history['accuracy'], marker='.', label='training accuracy')
plt.plot(history.history['val_accuracy'], marker='.', label='validation accuracy')
plt.plot(epoch,test_accuracy, marker='.')
plt.plot(epoch[0],test_accuracy[0], marker='.', label='Test accuracy')
plt.title(' accuracy')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.savefig('Task4_accuracyV1.jpeg')
plt.show()

# Loss plots
plt.plot(history.history['loss'], marker='.', label='training loss')
plt.plot(history.history['val_loss'], marker='.', label='validation loss')
plt.plot(epoch,test_loss, marker='.')
plt.plot(epoch[0],test_loss[0], marker='.',label='Test loss')
plt.title(' loss')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.savefig('Task4_lossV1.jpeg')
plt.show()
