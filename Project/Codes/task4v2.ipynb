# %%
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, SpatialDropout2D, BatchNormalization, Flatten, Activation, Conv2D, MaxPooling2D, Conv1D
from keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np

# Importing CIFAR 10 Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# train split to validation
x_train1, x_valid, y_train1, y_valid = train_test_split(x_train, y_train, test_size=0.2)

train_x = x_train1.astype('float32') / 255 
valid_x = x_valid.astype('float32') / 255
test_x = x_test.astype('float32') / 255

print(y_train1.shape)

N = 10

# One-hot encoding
train_y = to_categorical(y_train1, N).reshape(-1,1,1,10)
valid_y = to_categorical(y_valid, N).reshape(-1,1,1,10)
test_y = to_categorical(y_test, N).reshape(-1,1,1,10)
print(train_y.shape)
print(train_x.shape)
print(valid_x.shape)
print(test_x.shape)
# Out:
# (40000, 1)
# (40000, 1, 1, 10)
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def Model():
  
    Alex_model = Sequential()
    
    Alex_model.add(Conv2D(64, kernel_size=(3,3), strides = 2, padding='same', input_shape=(32, 32, 3))) # 1st Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2, padding='same'))
    
    Alex_model.add(Conv2D(192, kernel_size=(3,3), strides = 2, padding='same'))       # 2nd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(384, kernel_size=(3,3), strides = 2, padding='same'))       # 3rd Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 2, padding='same'))       # 4th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2),  strides = 2))
    
    Alex_model.add(Conv2D(256, kernel_size=(3,3), strides = 2, padding='same'))       # 5th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(SpatialDropout2D(rate=0.3))
    Alex_model.add(Activation('relu'))
    #Alex_model.add(MaxPooling2D(pool_size=(2,2), strides = 2))
    
    #Alex_model.add(Flatten())
    
    Alex_model.add(Conv2D(4096, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(4096))                     # 6th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Conv2D(4096, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(4096))                     # 7th Layer
    Alex_model.add(BatchNormalization())
    Alex_model.add(Activation('relu'))
    Alex_model.add(Dropout(rate=0.5))
    
    Alex_model.add(Conv2D(10, kernel_size=(1,1), strides = 1, padding='same'))
    #Alex_model.add(Dense(10))                       # 8th Layer
    Alex_model.add(Activation('softmax'))
    
    return Alex_model


Alex_model = Model()
Alex_model.compile(loss='categorical_crossentropy',
                   optimizer=tf.keras.optimizers.Adam(),
                   metrics=['accuracy'])
Alex_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 16, 16, 64)        1792
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# spatial_dropout2d_30 (Spatia (None, 16, 16, 64)        0
# _________________________________________________________________
# activation_31 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 192)         110784
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 8, 8, 192)         768
# _________________________________________________________________
# spatial_dropout2d_31 (Spatia (None, 8, 8, 192)         0
# _________________________________________________________________
# activation_32 (Activation)   (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 4, 4, 384)         663936
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 4, 4, 384)         1536
# _________________________________________________________________
# spatial_dropout2d_32 (Spatia (None, 4, 4, 384)         0
# _________________________________________________________________
# activation_33 (Activation)   (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_33 (Spatia (None, 2, 2, 256)         0
# _________________________________________________________________
# activation_34 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 1, 1, 256)         590080
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# spatial_dropout2d_34 (Spatia (None, 1, 1, 256)         0
# _________________________________________________________________
# activation_35 (Activation)   (None, 1, 1, 256)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 1, 1, 4096)        1052672
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 1, 1, 4096)        16384
# _________________________________________________________________
# activation_36 (Activation)   (None, 1, 1, 4096)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 1, 1, 4096)        16384
# _________________________________________________________________
# activation_37 (Activation)   (None, 1, 1, 4096)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# activation_38 (Activation)   (None, 1, 1, 10)          0
# =================================================================
# Total params: 20,163,914
# Trainable params: 20,145,226
# Non-trainable params: 18,688
# _________________________________________________________________

# %%
# verbose = progress bar setting
history = Alex_model.fit(train_x, train_y, batch_size=128, epochs=50, verbose=1, validation_data=(valid_x, valid_y))
# Out:
# Epoch 1/50
# 313/313 [==============================] - 10s 26ms/step - loss: 2.6154 - accuracy: 0.2387 - val_loss: 2.2391 - val_accuracy: 0.2180
# Epoch 2/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.8004 - accuracy: 0.3992 - val_loss: 2.7062 - val_accuracy: 0.4166
# Epoch 3/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.6770 - accuracy: 0.4543 - val_loss: 1.4640 - val_accuracy: 0.5107
# Epoch 4/50
# 313/313 [==============================] - 7s 24ms/step - loss: 1.5508 - accuracy: 0.4899 - val_loss: 1.2817 - val_accuracy: 0.5596
# Epoch 5/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.4319 - accuracy: 0.5336 - val_loss: 1.6371 - val_accuracy: 0.5365
# Epoch 6/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.3680 - accuracy: 0.5547 - val_loss: 1.1097 - val_accuracy: 0.6104
# Epoch 7/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.3495 - accuracy: 0.5647 - val_loss: 1.4452 - val_accuracy: 0.5066
# Epoch 8/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2240 - accuracy: 0.5987 - val_loss: 1.0731 - val_accuracy: 0.6214
# Epoch 9/50
# 313/313 [==============================] - 7s 24ms/step - loss: 1.1561 - accuracy: 0.6208 - val_loss: 1.0266 - val_accuracy: 0.6623
# Epoch 10/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1232 - accuracy: 0.6315 - val_loss: 1.1468 - val_accuracy: 0.6524
# Epoch 11/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0805 - accuracy: 0.6472 - val_loss: 1.0697 - val_accuracy: 0.6348
# Epoch 12/50
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0466 - accuracy: 0.6630 - val_loss: 0.9010 - val_accuracy: 0.6892
# Epoch 13/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.9711 - accuracy: 0.6757 - val_loss: 0.9274 - val_accuracy: 0.6982
# Epoch 14/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9454 - accuracy: 0.6820 - val_loss: 1.0937 - val_accuracy: 0.6290
# Epoch 15/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8915 - accuracy: 0.6986 - val_loss: 0.8641 - val_accuracy: 0.7086
# Epoch 16/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8817 - accuracy: 0.7072 - val_loss: 0.8802 - val_accuracy: 0.6975
# Epoch 17/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.8538 - accuracy: 0.7140 - val_loss: 0.8698 - val_accuracy: 0.7006
# Epoch 18/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7914 - accuracy: 0.7300 - val_loss: 0.8160 - val_accuracy: 0.7225
# Epoch 19/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7643 - accuracy: 0.7374 - val_loss: 0.8134 - val_accuracy: 0.7277
# Epoch 20/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7223 - accuracy: 0.7524 - val_loss: 0.8930 - val_accuracy: 0.7214
# Epoch 21/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7205 - accuracy: 0.7592 - val_loss: 0.8180 - val_accuracy: 0.7307
# Epoch 22/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7018 - accuracy: 0.7596 - val_loss: 0.9584 - val_accuracy: 0.7101
# Epoch 23/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6915 - accuracy: 0.7671 - val_loss: 0.7794 - val_accuracy: 0.7443
# Epoch 24/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6760 - accuracy: 0.7718 - val_loss: 0.8862 - val_accuracy: 0.7082
# Epoch 25/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6272 - accuracy: 0.7835 - val_loss: 0.7876 - val_accuracy: 0.7447
# Epoch 26/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.6057 - accuracy: 0.7948 - val_loss: 0.7781 - val_accuracy: 0.7489
# Epoch 27/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5909 - accuracy: 0.7971 - val_loss: 0.8622 - val_accuracy: 0.7223
# Epoch 28/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5857 - accuracy: 0.8002 - val_loss: 0.8143 - val_accuracy: 0.7410
# Epoch 29/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5526 - accuracy: 0.8138 - val_loss: 0.7756 - val_accuracy: 0.7544
# Epoch 30/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5489 - accuracy: 0.8124 - val_loss: 0.8671 - val_accuracy: 0.7254
# Epoch 31/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5504 - accuracy: 0.8124 - val_loss: 0.7766 - val_accuracy: 0.7501
# Epoch 32/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5010 - accuracy: 0.8261 - val_loss: 0.8684 - val_accuracy: 0.7303
# Epoch 33/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5506 - accuracy: 0.8215 - val_loss: 0.8432 - val_accuracy: 0.7410
# Epoch 34/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4871 - accuracy: 0.8348 - val_loss: 0.8127 - val_accuracy: 0.7491
# Epoch 35/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4967 - accuracy: 0.8352 - val_loss: 0.8971 - val_accuracy: 0.7141
# Epoch 36/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4954 - accuracy: 0.8342 - val_loss: 0.7964 - val_accuracy: 0.7547
# Epoch 37/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4547 - accuracy: 0.8445 - val_loss: 0.8566 - val_accuracy: 0.7431
# Epoch 38/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4146 - accuracy: 0.8569 - val_loss: 0.8457 - val_accuracy: 0.7421
# Epoch 39/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4119 - accuracy: 0.8578 - val_loss: 0.8298 - val_accuracy: 0.7527
# Epoch 40/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4173 - accuracy: 0.8576 - val_loss: 0.7971 - val_accuracy: 0.7555
# Epoch 41/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4330 - accuracy: 0.8570 - val_loss: 0.8623 - val_accuracy: 0.7391
# Epoch 42/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4170 - accuracy: 0.8570 - val_loss: 0.8096 - val_accuracy: 0.7549
# Epoch 43/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3951 - accuracy: 0.8680 - val_loss: 0.8416 - val_accuracy: 0.7611
# Epoch 44/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.3695 - accuracy: 0.8715 - val_loss: 0.8488 - val_accuracy: 0.7511
# Epoch 45/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3640 - accuracy: 0.8749 - val_loss: 0.8224 - val_accuracy: 0.7649
# Epoch 46/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3619 - accuracy: 0.8747 - val_loss: 0.8542 - val_accuracy: 0.7519
# Epoch 47/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3539 - accuracy: 0.8768 - val_loss: 0.8747 - val_accuracy: 0.7404
# Epoch 48/50
# 313/313 [==============================] - 7s 24ms/step - loss: 0.3595 - accuracy: 0.8765 - val_loss: 0.8813 - val_accuracy: 0.7477
# Epoch 49/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3578 - accuracy: 0.8783 - val_loss: 0.9097 - val_accuracy: 0.7409
# Epoch 50/50
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3410 - accuracy: 0.8824 - val_loss: 0.8516 - val_accuracy: 0.7608

# %%
score = Alex_model.evaluate(test_x, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.8905338048934937
# Test accuracy: 0.7433000206947327

# %%
test_accuracy=np.array([np.ones((50))*score[1]])
test_loss=np.array([np.ones((50))*score[0]])
epoch=np.array([np.linspace(1,50,50)])


# Accuracy plots
plt.plot(history.history['accuracy'], marker='.', label='training accuracy')
plt.plot(history.history['val_accuracy'], marker='.', label='validation accuracy')
plt.plot(epoch,test_accuracy, marker='.')
plt.plot(epoch[0],test_accuracy[0], marker='.', label='Test accuracy')
plt.title(' accuracy')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='best')
plt.savefig('Task4_accuracyV2.jpeg')
plt.show()

# Loss plots
plt.plot(history.history['loss'], marker='.', label='training loss')
plt.plot(history.history['val_loss'], marker='.', label='validation loss')
plt.plot(epoch,test_loss, marker='.')
plt.plot(epoch[0],test_loss[0], marker='.',label='Test loss')
plt.title(' loss')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.savefig('Task4_lossV2.jpeg')
plt.show()
